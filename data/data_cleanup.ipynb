# %% [markdown]
# # City Bike Data
# All of the data came from this website: https://www.citibikenyc.com/system-data
# The data was pulled in from csv files into dataframes. Years 2019 and 2020 were used, and each had 1 file/dataframe per each month of the year. The dataframes were originally going to be concatenated into one year. However, due to the size of the data. They were grouped into quarts with three months each for each year making 8 dataframes. Those dataframes were written to csv files.

# %%
import pandas as pd

# %%
bikes201901 = pd.read_csv("csv_files/201901-citibike-tripdata.csv")
bikes201901
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...              ...                       ...                       ...
# 967282           291  2019-01-31 17:33:26.4490  2019-01-31 17:38:17.8940
# 967283           437  2019-01-31 18:57:45.3380  2019-01-31 19:05:02.4970
# 967284           173  2019-01-31 19:11:41.1930  2019-01-31 19:14:34.3350
# 967285           244  2019-01-31 20:54:51.1440  2019-01-31 20:58:55.3100
# 967286           387  2019-01-31 23:38:42.1770  2019-01-31 23:45:09.4520
#
#         start station id           start station name  start station latitude  \
# ...

# %%
bikes201902 = pd.read_csv("csv_files/201902-citibike-tripdata.csv")
bikes201902.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
bikes201903 = pd.read_csv("csv_files/201903-citibike-tripdata.csv")
bikes201903.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1463  2019-03-01 00:00:16.0970  2019-03-01 00:24:39.3880
# 1           285  2019-03-01 00:00:32.3850  2019-03-01 00:05:18.1830
# 2           686  2019-03-01 00:00:47.7970  2019-03-01 00:12:14.3090
# 3           442  2019-03-01 00:01:01.2090  2019-03-01 00:08:23.7510
# 4          2913  2019-03-01 00:01:09.2810  2019-03-01 00:49:42.3810
#
#    start station id    start station name  start station latitude  \
# 0             319.0  Fulton St & Broadway               40.711066
# 1             439.0        E 4 St & 2 Ave               40.726281
# 2             526.0       E 33 St & 5 Ave               40.747659
# 3            3474.0     6 Ave & Spring St               40.725256
# 4             379.0       W 31 St & 7 Ave               40.749156
#
#    start station longitude  end station id             end station name  \
# 0               -74.009447           347.0  Greenwich St & W Houston St
# ...

# %%
bikes201904 = pd.read_csv("csv_files/201904-citibike-tripdata.csv")
bikes201904.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0            88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1           443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2           662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3            86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4           136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
#
#    start station id      start station name  start station latitude  \
# 0              2006  Central Park S & 6 Ave               40.765909
# 1               254         W 11 St & 6 Ave               40.735324
# 2              3244  University Pl & E 8 St               40.731437
# 3               526         E 33 St & 5 Ave               40.747659
# 4               461         E 20 St & 2 Ave               40.735877
#
#    start station longitude  end station id         end station name  \
# 0               -73.976342            2006   Central Park S & 6 Ave
# ...

# %%
bikes201905 = pd.read_csv("csv_files/201905-citibike-tripdata.csv")
bikes201905.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           139  2019-05-01 00:00:01.9010  2019-05-01 00:02:21.5170
# 1           754  2019-05-01 00:00:03.0210  2019-05-01 00:12:37.6920
# 2          2308  2019-05-01 00:00:04.6270  2019-05-01 00:38:33.1710
# 3           143  2019-05-01 00:00:19.3340  2019-05-01 00:02:42.5200
# 4           138  2019-05-01 00:00:22.1840  2019-05-01 00:02:40.6480
#
#    start station id         start station name  start station latitude  \
# 0               447            8 Ave & W 52 St               40.763707
# 1              3258           W 27 St & 10 Ave               40.750182
# 2              3093       N 6 St & Bedford Ave               40.717452
# 3              3486  Schermerhorn St & Bond St               40.688417
# 4               388           W 26 St & 10 Ave               40.749718
#
#    start station longitude  end station id            end station name  \
# ...

# %%
bikes201906 = pd.read_csv("csv_files/201906-citibike-tripdata.csv")
bikes201906.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           330  2019-06-01 00:00:01.5000  2019-06-01 00:05:31.7600
# 1           830  2019-06-01 00:00:04.2400  2019-06-01 00:13:55.1470
# 2           380  2019-06-01 00:00:06.0190  2019-06-01 00:06:26.7790
# 3          1155  2019-06-01 00:00:06.7760  2019-06-01 00:19:22.5380
# 4          1055  2019-06-01 00:00:07.5200  2019-06-01 00:17:42.5580
#
#    start station id       start station name  start station latitude  \
# 0              3602           31 Ave & 34 St               40.763154
# 1              3054  Greene Ave & Throop Ave               40.689493
# 2               229           Great Jones St               40.727434
# 3              3771  McKibbin St & Bogart St               40.706237
# 4               441          E 52 St & 2 Ave               40.756014
#
#    start station longitude  end station id       end station name  \
# 0               -73.920827            3570         35 Ave & 37 St
# ...

# %%
bikes201907 = pd.read_csv("csv_files/201907-citibike-tripdata.csv")
bikes201907.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1           267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2          2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3          1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4           109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
#
#    start station id       start station name  start station latitude  \
# 0             493.0          W 45 St & 6 Ave               40.756800
# 1            3143.0          5 Ave & E 78 St               40.776321
# 2             317.0        E 6 St & Avenue B               40.724537
# 3             249.0  Harrison St & Hudson St               40.718710
# 4            3552.0      W 113 St & Broadway               40.805973
#
#    start station longitude  end station id             end station name  \
# ...

# %%
bikes201908 = pd.read_csv("csv_files/201908-citibike-tripdata.csv")
bikes201908.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
bikes201909 = pd.read_csv("csv_files/201909-citibike-tripdata.csv")
bikes201909.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           327  2019-09-01 00:00:01.9580  2019-09-01 00:05:29.3410
# 1          1145  2019-09-01 00:00:04.1430  2019-09-01 00:19:09.8360
# 2          1293  2019-09-01 00:00:07.3090  2019-09-01 00:21:40.7580
# 3          1753  2019-09-01 00:00:08.0640  2019-09-01 00:29:21.5040
# 4           613  2019-09-01 00:00:12.8510  2019-09-01 00:10:26.1850
#
#    start station id           start station name  start station latitude  \
# 0              3733           Avenue C & E 18 St               40.730563
# 1              3329         Degraw St & Smith St               40.682915
# 2              3168  Central Park West & W 85 St               40.784727
# 3              3299           E 98 St & Park Ave               40.788130
# 4               486           Broadway & W 29 St               40.746201
#
#    start station longitude  end station id             end station name  \
# ...

# %%
bikes201910 = pd.read_csv("csv_files/201910-citibike-tripdata.csv")
bikes201910.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1           174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2           759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3           615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4           761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
#
#    start station id      start station name  start station latitude  \
# 0              3746       6 Ave & Broome St               40.724308
# 1              3301  Columbus Ave & W 95 St               40.791956
# 2               161   LaGuardia Pl & W 3 St               40.729170
# 3               254         W 11 St & 6 Ave               40.735324
# 4               161   LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id        end station name  \
# 0               -74.004730             223         W 13 St & 7 Ave
# ...

# %%
bikes201911 = pd.read_csv("csv_files/201911-citibike-tripdata.csv")
bikes201911.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           273  2019-11-01 00:00:00.2930  2019-11-01 00:04:34.1880
# 1           159  2019-11-01 00:00:03.5840  2019-11-01 00:02:43.4780
# 2           967  2019-11-01 00:00:06.2670  2019-11-01 00:16:14.0990
# 3           604  2019-11-01 00:00:21.7610  2019-11-01 00:10:25.8910
# 4           153  2019-11-01 00:00:25.2060  2019-11-01 00:02:59.0180
#
#    start station id     start station name  start station latitude  \
# 0               237        E 11 St & 2 Ave               40.730473
# 1              3572         34 Ave & 38 St               40.756913
# 2               334        W 20 St & 7 Ave               40.742388
# 3               280        E 10 St & 5 Ave               40.733320
# 4              3761  Cedar St & Myrtle Ave               40.697842
#
#    start station longitude  end station id          end station name  \
# 0               -73.986724             335  Washington Pl & Broadway
# ...

# %%
bikes201912 = pd.read_csv("csv_files/201912-citibike-tripdata.csv")
bikes201912.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1          1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2           723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3           404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4          1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
#
#    start station id      start station name  start station latitude  \
# 0              3382   Carroll St & Smith St               40.680611
# 1               362      Broadway & W 37 St               40.751726
# 2               146    Hudson St & Reade St               40.716250
# 3              3834  Irving Ave & Halsey St               40.694670
# 4               500      Broadway & W 51 St               40.762288
#
#    start station longitude  end station id              end station name  \
# ...

# %%
bikes202001 = pd.read_csv("csv_files/202001-citibike-tripdata.csv")
bikes202001.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
bikes202002 = pd.read_csv("csv_files/202002-citibike-tripdata.csv")
bikes202002.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1404  2020-02-01 00:00:05.9460  2020-02-01 00:23:30.7240
# 1          1301  2020-02-01 00:00:06.2230  2020-02-01 00:21:48.0580
# 2           474  2020-02-01 00:00:15.7210  2020-02-01 00:08:10.3440
# 3           487  2020-02-01 00:00:21.0520  2020-02-01 00:08:28.7520
# 4           619  2020-02-01 00:00:27.4000  2020-02-01 00:10:47.0640
#
#    start station id      start station name  start station latitude  \
# 0               316  Fulton St & William St               40.709560
# 1               237         E 11 St & 2 Ave               40.730473
# 2               528         2 Ave & E 31 St               40.742909
# 3               380        W 4 St & 7 Ave S               40.734011
# 4               472      E 32 St & Park Ave               40.745712
#
#    start station longitude  end station id                end station name  \
# ...

# %%
bikes202003 = pd.read_csv("csv_files/202003-citibike-tripdata.csv")
bikes202003.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1589  2020-03-01 00:00:03.6400  2020-03-01 00:26:32.9860
# 1           389  2020-03-01 00:00:16.7560  2020-03-01 00:06:46.0620
# 2           614  2020-03-01 00:00:20.0580  2020-03-01 00:10:34.2200
# 3           597  2020-03-01 00:00:24.3510  2020-03-01 00:10:22.3390
# 4          1920  2020-03-01 00:00:26.1120  2020-03-01 00:32:26.2680
#
#    start station id        start station name  start station latitude  \
# 0               224     Spruce St & Nassau St               40.711464
# 1               293     Lafayette St & E 8 St               40.730207
# 2               379           W 31 St & 7 Ave               40.749156
# 3              3739  Perry St & Greenwich Ave               40.735918
# 4               236       St Marks Pl & 2 Ave               40.728419
#
#    start station longitude  end station id             end station name  \
# ...

# %%
bikes202004 = pd.read_csv("csv_files/202004-citibike-tripdata.csv")
bikes202004.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1           529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2          1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3           341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4          2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
#
#    start station id           start station name  start station latitude  \
# 0              3656            E 2 St & Avenue A               40.723077
# 1              3163  Central Park West & W 68 St               40.773407
# 2              3164       Columbus Ave & W 72 St               40.777057
# 3              3827         Halsey St & Broadway               40.685650
# 4              3890          Grove St & Broadway               40.690470
#
#    start station longitude  end station id           end station name  \
# ...

# %%
bikes202005 = pd.read_csv("csv_files/202005-citibike-tripdata.csv")
bikes202005.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
#
#    start station id                  start station name  \
# 0              2017                     E 43 St & 2 Ave
# 1              3376                     E 65 St & 2 Ave
# 2               396          Lefferts Pl & Franklin Ave
# 3              3630  Frederick Douglass Blvd & W 115 St
# 4              3776          Central Ave & Starr Street
#
#    start station latitude  start station longitude  end station id  \
# 0               40.750224               -73.971214             465
# 1               40.764719               -73.962221             478
# ...

# %%
bikes202006 = pd.read_csv("csv_files/202006-citibike-tripdata.csv")
bikes202006.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1          3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2          1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3           226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4          1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
#
#    start station id        start station name  start station latitude  \
# 0              3419       Douglass St & 4 Ave               40.679279
# 1               366  Clinton Ave & Myrtle Ave               40.693261
# 2               389       Broadway & Berry St               40.710446
# 3              3255           8 Ave & W 31 St               40.750585
# 4               367   E 53 St & Lexington Ave               40.758281
#
#    start station longitude  end station id             end station name  \
# ...

# %%
bikes202007 = pd.read_csv("csv_files/202007-citibike-tripdata.csv")
bikes202007.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           341  2020-07-01 00:00:01.3020  2020-07-01 00:05:42.5650
# 1           321  2020-07-01 00:00:01.3620  2020-07-01 00:05:22.9490
# 2          2710  2020-07-01 00:00:06.6290  2020-07-01 00:45:17.3410
# 3          2685  2020-07-01 00:00:13.0220  2020-07-01 00:44:58.8640
# 4           191  2020-07-01 00:00:13.4660  2020-07-01 00:03:24.6230
#
#    start station id     start station name  start station latitude  \
# 0              3463    E 16 St & Irving Pl               40.735367
# 1              3463    E 16 St & Irving Pl               40.735367
# 2               426  West St & Chambers St               40.717548
# 3               426  West St & Chambers St               40.717548
# 4              3615          44 Dr & 21 St               40.748000
#
#    start station longitude  end station id         end station name  \
# 0               -73.987974            2003          1 Ave & E 18 St
# ...

# %%
bikes202008 = pd.read_csv("csv_files/202008-citibike-tripdata.csv")
bikes202008.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2013  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260
# 1          7002  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720
# 2           155  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340
# 3          2720  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270
# 4          2938  2020-08-01 00:00:05.9420  2020-08-01 00:49:03.9640
#
#    start station id                   start station name  \
# 0              3295             Central Park W & W 96 St
# 1              3144                   E 81 St & Park Ave
# 2               387              Centre St & Chambers St
# 3              3080                   S 4 St & Rodney St
# 4              3510  Adam Clayton Powell Blvd & W 123 St
#
#    start station latitude  start station longitude  end station id  \
# 0               40.791270               -73.964839            3992
# 1               40.776777               -73.959010            3671
# ...

# %%
bikes202009 = pd.read_csv("csv_files/202009-citibike-tripdata.csv")
bikes202009.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          4225  2020-09-01 00:00:01.0430  2020-09-01 01:10:26.6350
# 1          1868  2020-09-01 00:00:04.8320  2020-09-01 00:31:13.7650
# 2          1097  2020-09-01 00:00:06.8990  2020-09-01 00:18:24.2260
# 3          1473  2020-09-01 00:00:07.7440  2020-09-01 00:24:41.1800
# 4          1193  2020-09-01 00:00:12.2020  2020-09-01 00:20:05.5470
#
#    start station id               start station name  start station latitude  \
# 0              3508  St Nicholas Ave & Manhattan Ave               40.809725
# 1              3621                    27 Ave & 9 St               40.773983
# 2              3492              E 118 St & Park Ave               40.800539
# 3              3946       St Nicholas Ave & W 137 St               40.818477
# 4              3081            Graham Ave & Grand St               40.711863
#
#    start station longitude  end station id  \
# 0               -73.953149             116
# ...

# %%
bikes202010 = pd.read_csv("csv_files/202010-citibike-tripdata.csv")
bikes202010.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1           462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2           770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3           233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4           126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
#
#    start station id        start station name  start station latitude  \
# 0               224     Spruce St & Nassau St               40.711464
# 1              3161    W 76 St & Columbus Ave               40.780184
# 2               354   Emerson Pl & Myrtle Ave               40.693631
# 3              3141           1 Ave & E 68 St               40.765005
# 4               335  Washington Pl & Broadway               40.729039
#
#    start station longitude  end station id           end station name  \
# ...

# %%
bikes202011 = pd.read_csv("csv_files/202011-citibike-tripdata.csv")
bikes202011.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           521  2020-11-01 00:00:07.0150  2020-11-01 00:08:48.3010
# 1           492  2020-11-01 00:00:10.8080  2020-11-01 00:08:23.3170
# 2          1979  2020-11-01 00:00:14.7040  2020-11-01 00:33:14.1640
# 3          2382  2020-11-01 00:00:14.7070  2020-11-01 00:39:57.0030
# 4           166  2020-11-01 00:00:15.9690  2020-11-01 00:03:02.8980
#
#    start station id      start station name  start station latitude  \
# 0              3467  W Broadway & Spring St               40.724947
# 1              3557           40 Ave & 9 St               40.757420
# 2              3085    Roebling St & N 4 St               40.714690
# 3              3783    Cliff St & Fulton St               40.708380
# 4               422        W 59 St & 10 Ave               40.770513
#
#    start station longitude  end station id          end station name  \
# 0               -74.001659             350     Clinton St & Grand St
# ...

# %%
bikes202012 = pd.read_csv("csv_files/202012-citibike-tripdata.csv")
bikes202012.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1          4131  2020-12-01 00:00:09.1730  2020-12-01 01:09:00.2370
# 2          1368  2020-12-01 00:00:28.7470  2020-12-01 00:23:16.9980
# 3          1707  2020-12-01 00:00:34.7680  2020-12-01 00:29:02.6470
# 4          2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
#
#    start station id           start station name  start station latitude  \
# 0              4065     Wadsworth Ave & W 179 St               40.848467
# 1              3284           E 88 St & Park Ave               40.781411
# 2              3443              W 52 St & 6 Ave               40.761330
# 3                72             W 52 St & 11 Ave               40.767272
# 4              3165  Central Park West & W 72 St               40.775794
#
#    start station longitude  end station id          end station name  \
# ...

# %%
frames19_1 = [bikes201901, bikes201902, bikes201903]

# %%
frames19_2 = [bikes201904, bikes201905, bikes201906]

# %%
frames19_3 = [bikes201907, bikes201908, bikes201909]

# %%
frames19_4 = [bikes201910, bikes201911, bikes201912]

# %%
frames20_1 = [bikes202001, bikes202002, bikes202003]

# %%
frames20_2 = [bikes202004, bikes202005, bikes202006]

# %%
frames20_3 = [bikes202007, bikes202008, bikes202009]

# %%
frames20_4 = [bikes202010, bikes202011, bikes202012]

# %%
bikes2019_1 = pd.concat(frames19_1)

# %%
bikes2019_2 = pd.concat(frames19_2)

# %%
bikes2019_3 = pd.concat(frames19_3)

# %%
bikes2019_4 = pd.concat(frames19_4)

# %%
bikes2020_1 = pd.concat(frames20_1)

# %%
bikes2020_2 = pd.concat(frames20_2)

# %%
bikes2020_3 = pd.concat(frames20_3)

# %%
bikes2020_4 = pd.concat(frames20_4)

# %%
bikes2019_1
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 1327955           351  2019-03-31 23:59:30.5850  2019-04-01 00:05:21.7850
# 1327956          1943  2019-03-31 23:59:55.3410  2019-04-01 00:32:18.6920
# 1327957           515  2019-03-31 23:59:50.1810  2019-04-01 00:08:25.8330
# 1327958           660  2019-03-31 23:59:56.6520  2019-04-01 00:10:57.3760
# 1327959           132  2019-03-31 23:59:58.0230  2019-04-01 00:02:10.5920
#
#          start station id           start station name  \
# ...

# %%
bikes2019_2
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                  88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1                 443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2                 662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3                  86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4                 136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
# ...               ...                       ...                       ...
# 2125365           232  2019-06-30 23:59:32.8920  2019-07-01 00:03:25.6310
# 2125366           477  2019-06-30 23:59:33.6990  2019-07-01 00:07:31.0440
# 2125367           300  2019-06-30 23:59:47.4050  2019-07-01 00:04:48.1850
# 2125368           906  2019-06-30 23:59:51.5980  2019-07-01 00:14:58.3210
# 2125369          1270  2019-06-30 23:59:54.3670  2019-07-01 00:21:05.2750
#
#          start station id              start station name  \
# ...

# %%
bikes2019_3
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1                 267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2                2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3                1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4                 109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
# ...               ...                       ...                       ...
# 2444895          1764  2019-09-30 23:59:22.7670  2019-10-01 00:28:47.3180
# 2444896           378  2019-09-30 23:59:27.9270  2019-10-01 00:05:46.5700
# 2444897           561  2019-09-30 23:59:29.1450  2019-10-01 00:08:50.8070
# 2444898           311  2019-09-30 23:59:42.2520  2019-10-01 00:04:54.2320
# 2444899          1500  2019-09-30 23:59:55.3740  2019-10-01 00:24:55.8400
#
#          start station id       start station name  start station latitude  \
# ...

# %%
bikes2019_4
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                527  2019-10-01 00:00:05.6180  2019-10-01 00:08:52.9430
# 1                174  2019-10-01 00:00:15.8750  2019-10-01 00:03:10.1680
# 2                759  2019-10-01 00:00:19.8240  2019-10-01 00:12:59.7070
# 3                615  2019-10-01 00:00:21.0680  2019-10-01 00:10:36.6790
# 4                761  2019-10-01 00:00:26.3800  2019-10-01 00:13:08.3130
# ...              ...                       ...                       ...
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id                start station name  \
# ...

# %%
bikes2020_1
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 1068452           137  2020-03-31 23:56:06.0490  2020-03-31 23:58:23.3880
# 1068453          1548  2020-03-31 23:57:27.6850  2020-04-01 00:23:16.4110
# 1068454           308  2020-03-31 23:58:00.2690  2020-04-01 00:03:08.9500
# 1068455           872  2020-03-31 23:58:42.9010  2020-04-01 00:13:15.5860
# 1068456           306  2020-03-31 23:59:17.2580  2020-04-01 00:04:23.8880
#
#          start station id               start station name  \
# ...

# %%
bikes2020_2
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1                 529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2                1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3                 341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4                2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
# ...               ...                       ...                       ...
# 1882268           685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 1882269           446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 1882270           439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 1882271           890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 1882272           433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
#          start station id           start station name  \
# ...

# %%
bikes2020_3
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 341  2020-07-01 00:00:01.3020  2020-07-01 00:05:42.5650
# 1                 321  2020-07-01 00:00:01.3620  2020-07-01 00:05:22.9490
# 2                2710  2020-07-01 00:00:06.6290  2020-07-01 00:45:17.3410
# 3                2685  2020-07-01 00:00:13.0220  2020-07-01 00:44:58.8640
# 4                 191  2020-07-01 00:00:13.4660  2020-07-01 00:03:24.6230
# ...               ...                       ...                       ...
# 2488220          1818  2020-09-30 23:59:48.8460  2020-10-01 00:30:07.7810
# 2488221          1553  2020-09-30 23:59:53.7240  2020-10-01 00:25:47.1760
# 2488222           626  2020-09-30 23:59:54.6670  2020-10-01 00:10:21.6050
# 2488223           325  2020-09-30 23:59:56.2120  2020-10-01 00:05:21.3060
# 2488224           128  2020-09-30 23:59:57.8350  2020-10-01 00:02:06.0920
#
#          start station id           start station name  \
# ...

# %%
bikes2020_4
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1                 462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2                 770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3                 233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4                 126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
# ...               ...                       ...                       ...
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# ...

# %%
bikes2019_1.to_csv("bikes2019_1.csv")

# %%
bikes2019_2.to_csv("bikes2019_2.csv")

# %%
bikes2019_3.to_csv("bikes2019_3.csv")

# %%
bikes2019_4.to_csv("bikes2019_4.csv")

# %%
bikes2020_1.to_csv("bikes2020_1.csv")

# %%
bikes2020_2.to_csv("bikes2020_2.csv")

# %%
bikes2020_3.to_csv("bikes2020_3.csv")

# %%
bikes2020_4.to_csv("bikes2020_4.csv")
